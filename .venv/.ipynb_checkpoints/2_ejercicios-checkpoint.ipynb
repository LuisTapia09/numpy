# %% [markdown]
# # Analizando una Imagen

# %%
import matplotlib.pyplot as plt 
img = plt.imread('beagle.jpg')
img.shape

img[10,10]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 img = plt.imread('beagle.jpg')
#       3 img.shape
#       4
#       5 img[10,10]
#
# File ~/numpy/numpy/.venv/lib/python3.12/site-packages/matplotlib/pyplot.py:2614, in imread(fname, format)
#    2610 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2611 def imread(
#    2612         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2613 ) -> np.ndarray:
# -> 2614     return matplotlib.image.imread(fname, format)
#
# File ~/numpy/numpy/.venv/lib/python3.12/site-packages/matplotlib/image.py:1520, in imread(fname, format)
#    1513 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1514     # Pillow doesn't handle URLs directly.
#    1515     raise ValueError(
# ...
